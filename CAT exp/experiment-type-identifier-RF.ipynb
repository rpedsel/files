# %% [markdown]
# RF:
#     default clf:
#         - precision = 0.9356
#         - recall = 0.867
#         - f1(binary) = 0.895
#     grid search:
#         - on precision:
#             precision = 0.92
#             recall = 0.85
#             f1(binary?) = 0.88
#         - on recall:
#             precision = 0.86
#             recall = 0.92
#             f1(binary?) = 0.89
#         - on f1:
#             precision = 0.96
#             recall = 0.92
#             f1(binary?) = 0.94
# Rule-based:
#     - f1(binary?) = 0.823529411765
#     - precision = 0.768292682927

# %%
import pandas as pd
import numpy as np
from __future__ import print_function
from sklearn import preprocessing
from sklearn.metrics import f1_score
from sklearn.model_selection import cross_validate

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score

# %%
# columns collected from 14 datasets (D3M seeds, UCI)
original = pd.read_csv("manually_labeled_dataset.csv")
#original

# %%
# columns collected from 8 datasets (openML, labels from ARFF)
external = pd.read_csv("testset.csv")
#external

# %%
# concat the two datasets
data = pd.concat([original, external],ignore_index=True)

# %%
# get rid of the case where ID be marked as categorical
data = data[data['col_name']!='RIVER']
# get rid of binary
data = data[(data.type != 'binary') & (data.type != 'empty')]
# make type other than categorical -> 'not categorical'
data.loc[data['type'] != 'categorical', 'type'] = False
data.loc[data['type'] == 'categorical', 'type'] = True
data['type'] = data['type'].astype(bool)
# dtype to int
data.loc[data['dtype'] == 'int64' , 'dtype'] = 0
data.loc[data['dtype'] == 'float64' , 'dtype'] = 1
data.loc[data['dtype'] == 'object' , 'dtype'] = 2
# 95%in10 to int
data['95%in10'] = data['95%in10'].astype(int)

# %%
#data

# %%
data.type.value_counts()
# Out:
# False    315
# True      71
# Name: type, dtype: int64

# %%
features = list(data.drop(['type','col_name'],axis=1).columns)

#y = data["type"].astype(int)
X = data[features]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=0)

scoring = ['precision', 'recall', 'f1']

# %%
# default classifier
clf = RandomForestClassifier(random_state=0)
crsv = cross_validate(clf, X_train, y_train, cv=5,scoring=scoring)

# %%
print('train_f1_macro: ', crsv['train_f1'].mean())
print('test_f1_macro: ', crsv['test_f1'].mean())
print('train_precision: ', crsv['train_precision'].mean())
print('test_precision: ', crsv['test_precision'].mean())
print('train_recall: ', crsv['train_recall'].mean())
print('test_recall: ', crsv['test_recall'].mean())
# Out:
# train_f1_macro:  0.988732394366
# test_f1_macro:  0.895029239766
# train_precision:  1.0
# test_precision:  0.935555555556
# train_recall:  0.977777777778
# test_recall:  0.866666666667

# %%
for score in scoring:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    CV_clf = GridSearchCV(estimator=RandomForestClassifier(random_state=0), 
                          param_grid=param_grid, cv= 5,scoring=score)

    CV_clf.fit(X_train, y_train)

    print("Best parameters set found on training set:")
    print()
    print(CV_clf.best_params_)
    print()
    print("Grid scores on training set:")
    print()
    means = CV_clf.cv_results_['mean_test_score']
    stds = CV_clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, CV_clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full training set.")
    print("The scores are computed on the full test set.")
    print()
    y_true, y_pred = y_test, CV_clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for precision
#
# Best parameters set found on training set:
#
# {'max_features': None, 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 2}
#
# Grid scores on training set:
#
# 0.771 (+/-0.292) for {'max_features': 'auto', 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 2}
# 0.788 (+/-0.469) for {'max_features': 'auto', 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 2}
# 0.782 (+/-0.487) for {'max_features': 'auto', 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 2}
# 0.801 (+/-0.418) for {'max_features': 'auto', 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 2}
# 0.860 (+/-0.277) for {'max_features': 'auto', 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 2}
# 0.771 (+/-0.292) for {'max_features': 'log2', 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 2}
# 0.788 (+/-0.469) for {'max_features': 'log2', 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 2}
# 0.782 (+/-0.487) for {'max_features': 'log2', 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 2}
# 0.801 (+/-0.418) for {'max_features': 'log2', 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 2}
# 0.860 (+/-0.277) for {'max_features': 'log2', 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 2}
# 0.978 (+/-0.089) for {'max_features': None, 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 2}
# 0.960 (+/-0.160) for {'max_features': None, 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 2}
# 0.940 (+/-0.160) for {'max_features': None, 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 2}
# 0.960 (+/-0.160) for {'max_features': None, 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 2}
# 0.960 (+/-0.160) for {'max_features': None, 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 2}
# 0.855 (+/-0.241) for {'max_features': 'auto', 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 4}
# 0.891 (+/-0.244) for {'max_features': 'auto', 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 4}
# 0.879 (+/-0.199) for {'max_features': 'auto', 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 4}
# 0.960 (+/-0.160) for {'max_features': 'auto', 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 4}
# 0.978 (+/-0.089) for {'max_features': 'auto', 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 4}
# 0.855 (+/-0.241) for {'max_features': 'log2', 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 4}
# 0.891 (+/-0.244) for {'max_features': 'log2', 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 4}
# 0.879 (+/-0.199) for {'max_features': 'log2', 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 4}
# 0.960 (+/-0.160) for {'max_features': 'log2', 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 4}
# 0.978 (+/-0.089) for {'max_features': 'log2', 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 4}
# 0.938 (+/-0.162) for {'max_features': None, 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 4}
# 0.953 (+/-0.116) for {'max_features': None, 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 4}
# 0.978 (+/-0.089) for {'max_features': None, 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 4}
# 0.978 (+/-0.089) for {'max_features': None, 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 4}
# 0.978 (+/-0.089) for {'max_features': None, 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 4}
# 0.860 (+/-0.160) for {'max_features': 'auto', 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 8}
# 0.936 (+/-0.176) for {'max_features': 'auto', 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 8}
# 0.918 (+/-0.151) for {'max_features': 'auto', 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 8}
# 0.918 (+/-0.151) for {'max_features': 'auto', 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 8}
# 0.956 (+/-0.109) for {'max_features': 'auto', 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 8}
# 0.860 (+/-0.160) for {'max_features': 'log2', 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 8}
# 0.936 (+/-0.176) for {'max_features': 'log2', 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 8}
# 0.918 (+/-0.151) for {'max_features': 'log2', 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 8}
# 0.918 (+/-0.151) for {'max_features': 'log2', 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 8}
# 0.956 (+/-0.109) for {'max_features': 'log2', 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 8}
# 0.938 (+/-0.162) for {'max_features': None, 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 8}
# 0.953 (+/-0.116) for {'max_features': None, 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 8}
# 0.978 (+/-0.089) for {'max_features': None, 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 8}
# 0.978 (+/-0.089) for {'max_features': None, 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 8}
# 0.978 (+/-0.089) for {'max_features': None, 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 8}
# 0.860 (+/-0.160) for {'max_features': 'auto', 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 10}
# 0.936 (+/-0.176) for {'max_features': 'auto', 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10}
# 0.918 (+/-0.151) for {'max_features': 'auto', 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10}
# 0.918 (+/-0.151) for {'max_features': 'auto', 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10}
# 0.956 (+/-0.109) for {'max_features': 'auto', 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 10}
# 0.860 (+/-0.160) for {'max_features': 'log2', 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 10}
# 0.936 (+/-0.176) for {'max_features': 'log2', 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10}
# 0.918 (+/-0.151) for {'max_features': 'log2', 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10}
# 0.918 (+/-0.151) for {'max_features': 'log2', 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10}
# 0.956 (+/-0.109) for {'max_features': 'log2', 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 10}
# 0.938 (+/-0.162) for {'max_features': None, 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 10}
# 0.953 (+/-0.116) for {'max_features': None, 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10}
# 0.978 (+/-0.089) for {'max_features': None, 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10}
# 0.978 (+/-0.089) for {'max_features': None, 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10}
# 0.978 (+/-0.089) for {'max_features': None, 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 10}
# 0.827 (+/-0.126) for {'max_features': 'auto', 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 2}
# 0.810 (+/-0.336) for {'max_features': 'auto', 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 2}
# 0.800 (+/-0.438) for {'max_features': 'auto', 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 2}
# 0.800 (+/-0.438) for {'max_features': 'auto', 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 2}
# 0.873 (+/-0.223) for {'max_features': 'auto', 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 2}
# 0.827 (+/-0.126) for {'max_features': 'log2', 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 2}
# 0.810 (+/-0.336) for {'max_features': 'log2', 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 2}
# 0.800 (+/-0.438) for {'max_features': 'log2', 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 2}
# 0.800 (+/-0.438) for {'max_features': 'log2', 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 2}
# 0.873 (+/-0.223) for {'max_features': 'log2', 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 2}
# 0.980 (+/-0.080) for {'max_features': None, 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 2}
# 0.940 (+/-0.160) for {'max_features': None, 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 2}
# 0.978 (+/-0.089) for {'max_features': None, 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 2}
# 0.978 (+/-0.089) for {'max_features': None, 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 2}
# 0.945 (+/-0.218) for {'max_features': None, 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 2}
# 0.898 (+/-0.179) for {'max_features': 'auto', 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 4}
# 0.960 (+/-0.160) for {'max_features': 'auto', 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 4}
# 0.936 (+/-0.106) for {'max_features': 'auto', 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 4}
# 0.958 (+/-0.104) for {'max_features': 'auto', 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 4}
# 0.980 (+/-0.080) for {'max_features': 'auto', 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 4}
# 0.898 (+/-0.179) for {'max_features': 'log2', 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 4}
# 0.960 (+/-0.160) for {'max_features': 'log2', 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 4}
# 0.936 (+/-0.106) for {'max_features': 'log2', 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 4}
# 0.958 (+/-0.104) for {'max_features': 'log2', 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 4}
# 0.980 (+/-0.080) for {'max_features': 'log2', 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 4}
# 0.924 (+/-0.187) for {'max_features': None, 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 4}
# 0.953 (+/-0.116) for {'max_features': None, 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 4}
# 0.978 (+/-0.089) for {'max_features': None, 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 4}
# 0.978 (+/-0.089) for {'max_features': None, 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 4}
# 0.978 (+/-0.089) for {'max_features': None, 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 4}
# 0.855 (+/-0.092) for {'max_features': 'auto', 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 8}
# 0.978 (+/-0.089) for {'max_features': 'auto', 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 8}
# 0.958 (+/-0.104) for {'max_features': 'auto', 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 8}
# 0.978 (+/-0.089) for {'max_features': 'auto', 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 8}
# 0.956 (+/-0.109) for {'max_features': 'auto', 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 8}
# 0.855 (+/-0.092) for {'max_features': 'log2', 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 8}
# 0.978 (+/-0.089) for {'max_features': 'log2', 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 8}
# 0.958 (+/-0.104) for {'max_features': 'log2', 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 8}
# 0.978 (+/-0.089) for {'max_features': 'log2', 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 8}
# 0.956 (+/-0.109) for {'max_features': 'log2', 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 8}
# 0.938 (+/-0.162) for {'max_features': None, 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 8}
# 0.953 (+/-0.116) for {'max_features': None, 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 8}
# 0.978 (+/-0.089) for {'max_features': None, 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 8}
# 0.978 (+/-0.089) for {'max_features': None, 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 8}
# 0.978 (+/-0.089) for {'max_features': None, 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 8}
# 0.855 (+/-0.092) for {'max_features': 'auto', 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 10}
# 0.978 (+/-0.089) for {'max_features': 'auto', 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 10}
# 0.958 (+/-0.104) for {'max_features': 'auto', 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 10}
# 0.978 (+/-0.089) for {'max_features': 'auto', 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 10}
# 0.956 (+/-0.109) for {'max_features': 'auto', 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 10}
# 0.855 (+/-0.092) for {'max_features': 'log2', 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 10}
# 0.978 (+/-0.089) for {'max_features': 'log2', 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 10}
# 0.958 (+/-0.104) for {'max_features': 'log2', 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 10}
# 0.978 (+/-0.089) for {'max_features': 'log2', 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 10}
# 0.956 (+/-0.109) for {'max_features': 'log2', 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 10}
# 0.938 (+/-0.162) for {'max_features': None, 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 10}
# 0.953 (+/-0.116) for {'max_features': None, 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 10}
# 0.978 (+/-0.089) for {'max_features': None, 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 10}
# 0.978 (+/-0.089) for {'max_features': None, 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 10}
# 0.978 (+/-0.089) for {'max_features': None, 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 10}
#
# Detailed classification report:
#
# The model is trained on the full training set.
# The scores are computed on the full test set.
#
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97        90
#           1       0.92      0.85      0.88        26
#
# avg / total       0.95      0.95      0.95       116
#
#
# # Tuning hyper-parameters for recall
# Best parameters set found on training set:
#
# {'max_features': 'auto', 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 4}
#
# Grid scores on training set:
#
# 0.822 (+/-0.606) for {'max_features': 'auto', 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 2}
# 0.800 (+/-0.586) for {'max_features': 'auto', 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 2}
# 0.733 (+/-0.537) for {'max_features': 'auto', 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 2}
# 0.756 (+/-0.453) for {'max_features': 'auto', 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 2}
# 0.800 (+/-0.356) for {'max_features': 'auto', 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 2}
# 0.822 (+/-0.606) for {'max_features': 'log2', 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 2}
# 0.800 (+/-0.586) for {'max_features': 'log2', 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 2}
# 0.733 (+/-0.537) for {'max_features': 'log2', 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 2}
# 0.756 (+/-0.453) for {'max_features': 'log2', 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 2}
# 0.800 (+/-0.356) for {'max_features': 'log2', 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 2}
# 0.844 (+/-0.227) for {'max_features': None, 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 2}
# 0.844 (+/-0.227) for {'max_features': None, 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 2}
# 0.867 (+/-0.259) for {'max_features': None, 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 2}
# 0.844 (+/-0.227) for {'max_features': None, 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 2}
# 0.844 (+/-0.227) for {'max_features': None, 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 2}
# 0.956 (+/-0.109) for {'max_features': 'auto', 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 4}
# 0.889 (+/-0.243) for {'max_features': 'auto', 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 4}
# 0.889 (+/-0.199) for {'max_features': 'auto', 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 4}
# 0.911 (+/-0.166) for {'max_features': 'auto', 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 4}
# 0.911 (+/-0.166) for {'max_features': 'auto', 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 4}
# 0.956 (+/-0.109) for {'max_features': 'log2', 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 4}
# 0.889 (+/-0.243) for {'max_features': 'log2', 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 4}
# 0.889 (+/-0.199) for {'max_features': 'log2', 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 4}
# 0.911 (+/-0.166) for {'max_features': 'log2', 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 4}
# 0.911 (+/-0.166) for {'max_features': 'log2', 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 4}
# 0.911 (+/-0.166) for {'max_features': None, 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 4}
# 0.889 (+/-0.199) for {'max_features': None, 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 4}
# 0.911 (+/-0.166) for {'max_features': None, 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 4}
# 0.911 (+/-0.166) for {'max_features': None, 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 4}
# 0.911 (+/-0.166) for {'max_features': None, 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 4}
# 0.933 (+/-0.109) for {'max_features': 'auto', 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 8}
# 0.867 (+/-0.218) for {'max_features': 'auto', 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 8}
# 0.911 (+/-0.166) for {'max_features': 'auto', 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 8}
# 0.911 (+/-0.166) for {'max_features': 'auto', 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 8}
# 0.911 (+/-0.166) for {'max_features': 'auto', 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 8}
# 0.933 (+/-0.109) for {'max_features': 'log2', 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 8}
# 0.867 (+/-0.218) for {'max_features': 'log2', 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 8}
# 0.911 (+/-0.166) for {'max_features': 'log2', 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 8}
# 0.911 (+/-0.166) for {'max_features': 'log2', 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 8}
# 0.911 (+/-0.166) for {'max_features': 'log2', 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 8}
# 0.911 (+/-0.166) for {'max_features': None, 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 8}
# 0.889 (+/-0.199) for {'max_features': None, 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 8}
# 0.911 (+/-0.166) for {'max_features': None, 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 8}
# 0.911 (+/-0.166) for {'max_features': None, 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 8}
# 0.911 (+/-0.166) for {'max_features': None, 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 8}
# 0.933 (+/-0.109) for {'max_features': 'auto', 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 10}
# 0.867 (+/-0.218) for {'max_features': 'auto', 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10}
# 0.911 (+/-0.166) for {'max_features': 'auto', 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10}
# 0.911 (+/-0.166) for {'max_features': 'auto', 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10}
# 0.911 (+/-0.166) for {'max_features': 'auto', 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 10}
# 0.933 (+/-0.109) for {'max_features': 'log2', 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 10}
# 0.867 (+/-0.218) for {'max_features': 'log2', 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10}
# 0.911 (+/-0.166) for {'max_features': 'log2', 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10}
# 0.911 (+/-0.166) for {'max_features': 'log2', 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10}
# 0.911 (+/-0.166) for {'max_features': 'log2', 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 10}
# 0.911 (+/-0.166) for {'max_features': None, 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 10}
# 0.889 (+/-0.199) for {'max_features': None, 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10}
# 0.911 (+/-0.166) for {'max_features': None, 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10}
# 0.911 (+/-0.166) for {'max_features': None, 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10}
# 0.911 (+/-0.166) for {'max_features': None, 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 10}
# 0.933 (+/-0.109) for {'max_features': 'auto', 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 2}
# 0.711 (+/-0.590) for {'max_features': 'auto', 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 2}
# 0.667 (+/-0.579) for {'max_features': 'auto', 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 2}
# 0.667 (+/-0.579) for {'max_features': 'auto', 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 2}
# 0.778 (+/-0.398) for {'max_features': 'auto', 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 2}
# 0.933 (+/-0.109) for {'max_features': 'log2', 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 2}
# 0.711 (+/-0.590) for {'max_features': 'log2', 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 2}
# 0.667 (+/-0.579) for {'max_features': 'log2', 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 2}
# 0.667 (+/-0.579) for {'max_features': 'log2', 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 2}
# 0.778 (+/-0.398) for {'max_features': 'log2', 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 2}
# 0.867 (+/-0.259) for {'max_features': None, 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 2}
# 0.844 (+/-0.227) for {'max_features': None, 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 2}
# 0.844 (+/-0.227) for {'max_features': None, 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 2}
# 0.844 (+/-0.227) for {'max_features': None, 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 2}
# 0.844 (+/-0.227) for {'max_features': None, 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 2}
# 0.911 (+/-0.089) for {'max_features': 'auto', 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 4}
# 0.889 (+/-0.199) for {'max_features': 'auto', 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 4}
# 0.911 (+/-0.166) for {'max_features': 'auto', 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 4}
# 0.889 (+/-0.199) for {'max_features': 'auto', 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 4}
# 0.911 (+/-0.166) for {'max_features': 'auto', 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 4}
# 0.911 (+/-0.089) for {'max_features': 'log2', 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 4}
# 0.889 (+/-0.199) for {'max_features': 'log2', 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 4}
# 0.911 (+/-0.166) for {'max_features': 'log2', 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 4}
# 0.889 (+/-0.199) for {'max_features': 'log2', 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 4}
# 0.911 (+/-0.166) for {'max_features': 'log2', 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 4}
# 0.911 (+/-0.166) for {'max_features': None, 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 4}
# 0.889 (+/-0.199) for {'max_features': None, 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 4}
# 0.889 (+/-0.199) for {'max_features': None, 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 4}
# 0.889 (+/-0.199) for {'max_features': None, 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 4}
# 0.889 (+/-0.199) for {'max_features': None, 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 4}
# 0.911 (+/-0.166) for {'max_features': 'auto', 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 8}
# 0.889 (+/-0.199) for {'max_features': 'auto', 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 8}
# 0.911 (+/-0.166) for {'max_features': 'auto', 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 8}
# 0.911 (+/-0.166) for {'max_features': 'auto', 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 8}
# 0.911 (+/-0.166) for {'max_features': 'auto', 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 8}
# 0.911 (+/-0.166) for {'max_features': 'log2', 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 8}
# 0.889 (+/-0.199) for {'max_features': 'log2', 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 8}
# 0.911 (+/-0.166) for {'max_features': 'log2', 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 8}
# 0.911 (+/-0.166) for {'max_features': 'log2', 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 8}
# 0.911 (+/-0.166) for {'max_features': 'log2', 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 8}
# 0.889 (+/-0.141) for {'max_features': None, 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 8}
# 0.889 (+/-0.199) for {'max_features': None, 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 8}
# 0.911 (+/-0.166) for {'max_features': None, 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 8}
# 0.911 (+/-0.166) for {'max_features': None, 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 8}
# 0.911 (+/-0.166) for {'max_features': None, 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 8}
# 0.911 (+/-0.166) for {'max_features': 'auto', 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 10}
# 0.889 (+/-0.199) for {'max_features': 'auto', 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 10}
# 0.911 (+/-0.166) for {'max_features': 'auto', 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 10}
# 0.911 (+/-0.166) for {'max_features': 'auto', 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 10}
# 0.911 (+/-0.166) for {'max_features': 'auto', 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 10}
# 0.911 (+/-0.166) for {'max_features': 'log2', 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 10}
# 0.889 (+/-0.199) for {'max_features': 'log2', 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 10}
# 0.911 (+/-0.166) for {'max_features': 'log2', 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 10}
# 0.911 (+/-0.166) for {'max_features': 'log2', 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 10}
# 0.911 (+/-0.166) for {'max_features': 'log2', 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 10}
# 0.889 (+/-0.141) for {'max_features': None, 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 10}
# 0.889 (+/-0.199) for {'max_features': None, 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 10}
# 0.911 (+/-0.166) for {'max_features': None, 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 10}
# 0.911 (+/-0.166) for {'max_features': None, 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 10}
# 0.911 (+/-0.166) for {'max_features': None, 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 10}
#
# Detailed classification report:
#
# The model is trained on the full training set.
# The scores are computed on the full test set.
#
#              precision    recall  f1-score   support
#
#           0       0.98      0.96      0.97        90
#           1       0.86      0.92      0.89        26
#
# avg / total       0.95      0.95      0.95       116
#
#
# # Tuning hyper-parameters for f1
# Best parameters set found on training set:
#
# {'max_features': 'auto', 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 4}
#
# Grid scores on training set:
#
# 0.780 (+/-0.476) for {'max_features': 'auto', 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 2}
# 0.789 (+/-0.524) for {'max_features': 'auto', 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 2}
# 0.752 (+/-0.507) for {'max_features': 'auto', 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 2}
# 0.774 (+/-0.424) for {'max_features': 'auto', 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 2}
# 0.823 (+/-0.283) for {'max_features': 'auto', 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 2}
# 0.780 (+/-0.476) for {'max_features': 'log2', 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 2}
# 0.789 (+/-0.524) for {'max_features': 'log2', 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 2}
# 0.752 (+/-0.507) for {'max_features': 'log2', 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 2}
# 0.774 (+/-0.424) for {'max_features': 'log2', 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 2}
# 0.823 (+/-0.283) for {'max_features': 'log2', 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 2}
# 0.901 (+/-0.134) for {'max_features': None, 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 2}
# 0.892 (+/-0.142) for {'max_features': None, 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 2}
# 0.893 (+/-0.144) for {'max_features': None, 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 2}
# 0.892 (+/-0.142) for {'max_features': None, 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 2}
# 0.892 (+/-0.142) for {'max_features': None, 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 2}
# 0.900 (+/-0.168) for {'max_features': 'auto', 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 4}
# 0.889 (+/-0.233) for {'max_features': 'auto', 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 4}
# 0.879 (+/-0.146) for {'max_features': 'auto', 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 4}
# 0.932 (+/-0.129) for {'max_features': 'auto', 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 4}
# 0.941 (+/-0.106) for {'max_features': 'auto', 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 4}
# 0.900 (+/-0.168) for {'max_features': 'log2', 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 4}
# 0.889 (+/-0.233) for {'max_features': 'log2', 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 4}
# 0.879 (+/-0.146) for {'max_features': 'log2', 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 4}
# 0.932 (+/-0.129) for {'max_features': 'log2', 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 4}
# 0.941 (+/-0.106) for {'max_features': 'log2', 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 4}
# 0.921 (+/-0.132) for {'max_features': None, 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 4}
# 0.917 (+/-0.142) for {'max_features': None, 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 4}
# 0.941 (+/-0.106) for {'max_features': None, 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 4}
# 0.941 (+/-0.106) for {'max_features': None, 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 4}
# 0.941 (+/-0.106) for {'max_features': None, 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 4}
# 0.895 (+/-0.133) for {'max_features': 'auto', 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 8}
# 0.895 (+/-0.150) for {'max_features': 'auto', 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 8}
# 0.911 (+/-0.112) for {'max_features': 'auto', 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 8}
# 0.911 (+/-0.112) for {'max_features': 'auto', 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 8}
# 0.931 (+/-0.114) for {'max_features': 'auto', 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 8}
# 0.895 (+/-0.133) for {'max_features': 'log2', 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 8}
# 0.895 (+/-0.150) for {'max_features': 'log2', 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 8}
# 0.911 (+/-0.112) for {'max_features': 'log2', 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 8}
# 0.911 (+/-0.112) for {'max_features': 'log2', 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 8}
# 0.931 (+/-0.114) for {'max_features': 'log2', 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 8}
# 0.921 (+/-0.132) for {'max_features': None, 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 8}
# 0.917 (+/-0.142) for {'max_features': None, 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 8}
# 0.941 (+/-0.106) for {'max_features': None, 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 8}
# 0.941 (+/-0.106) for {'max_features': None, 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 8}
# 0.941 (+/-0.106) for {'max_features': None, 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 8}
# 0.895 (+/-0.133) for {'max_features': 'auto', 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 10}
# 0.895 (+/-0.150) for {'max_features': 'auto', 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10}
# 0.911 (+/-0.112) for {'max_features': 'auto', 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10}
# 0.911 (+/-0.112) for {'max_features': 'auto', 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10}
# 0.931 (+/-0.114) for {'max_features': 'auto', 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 10}
# 0.895 (+/-0.133) for {'max_features': 'log2', 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 10}
# 0.895 (+/-0.150) for {'max_features': 'log2', 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10}
# 0.911 (+/-0.112) for {'max_features': 'log2', 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10}
# 0.911 (+/-0.112) for {'max_features': 'log2', 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10}
# 0.931 (+/-0.114) for {'max_features': 'log2', 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 10}
# 0.921 (+/-0.132) for {'max_features': None, 'n_estimators': 3, 'criterion': 'gini', 'max_depth': 10}
# 0.917 (+/-0.142) for {'max_features': None, 'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10}
# 0.941 (+/-0.106) for {'max_features': None, 'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10}
# 0.941 (+/-0.106) for {'max_features': None, 'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10}
# 0.941 (+/-0.106) for {'max_features': None, 'n_estimators': 200, 'criterion': 'gini', 'max_depth': 10}
# 0.876 (+/-0.101) for {'max_features': 'auto', 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 2}
# 0.739 (+/-0.473) for {'max_features': 'auto', 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 2}
# 0.715 (+/-0.512) for {'max_features': 'auto', 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 2}
# 0.715 (+/-0.512) for {'max_features': 'auto', 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 2}
# 0.813 (+/-0.287) for {'max_features': 'auto', 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 2}
# 0.876 (+/-0.101) for {'max_features': 'log2', 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 2}
# 0.739 (+/-0.473) for {'max_features': 'log2', 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 2}
# 0.715 (+/-0.512) for {'max_features': 'log2', 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 2}
# 0.715 (+/-0.512) for {'max_features': 'log2', 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 2}
# 0.813 (+/-0.287) for {'max_features': 'log2', 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 2}
# 0.913 (+/-0.138) for {'max_features': None, 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 2}
# 0.881 (+/-0.114) for {'max_features': None, 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 2}
# 0.901 (+/-0.134) for {'max_features': None, 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 2}
# 0.901 (+/-0.134) for {'max_features': None, 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 2}
# 0.883 (+/-0.157) for {'max_features': None, 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 2}
# 0.903 (+/-0.122) for {'max_features': 'auto', 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 4}
# 0.918 (+/-0.135) for {'max_features': 'auto', 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 4}
# 0.920 (+/-0.094) for {'max_features': 'auto', 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 4}
# 0.917 (+/-0.099) for {'max_features': 'auto', 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 4}
# 0.941 (+/-0.079) for {'max_features': 'auto', 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 4}
# 0.903 (+/-0.122) for {'max_features': 'log2', 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 4}
# 0.918 (+/-0.135) for {'max_features': 'log2', 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 4}
# 0.920 (+/-0.094) for {'max_features': 'log2', 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 4}
# 0.917 (+/-0.099) for {'max_features': 'log2', 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 4}
# 0.941 (+/-0.079) for {'max_features': 'log2', 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 4}
# 0.912 (+/-0.110) for {'max_features': None, 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 4}
# 0.917 (+/-0.142) for {'max_features': None, 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 4}
# 0.928 (+/-0.118) for {'max_features': None, 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 4}
# 0.928 (+/-0.118) for {'max_features': None, 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 4}
# 0.928 (+/-0.118) for {'max_features': None, 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 4}
# 0.880 (+/-0.110) for {'max_features': 'auto', 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 8}
# 0.928 (+/-0.118) for {'max_features': 'auto', 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 8}
# 0.930 (+/-0.090) for {'max_features': 'auto', 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 8}
# 0.941 (+/-0.106) for {'max_features': 'auto', 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 8}
# 0.931 (+/-0.114) for {'max_features': 'auto', 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 8}
# 0.880 (+/-0.110) for {'max_features': 'log2', 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 8}
# 0.928 (+/-0.118) for {'max_features': 'log2', 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 8}
# 0.930 (+/-0.090) for {'max_features': 'log2', 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 8}
# 0.941 (+/-0.106) for {'max_features': 'log2', 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 8}
# 0.931 (+/-0.114) for {'max_features': 'log2', 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 8}
# 0.909 (+/-0.111) for {'max_features': None, 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 8}
# 0.917 (+/-0.142) for {'max_features': None, 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 8}
# 0.941 (+/-0.106) for {'max_features': None, 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 8}
# 0.941 (+/-0.106) for {'max_features': None, 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 8}
# 0.941 (+/-0.106) for {'max_features': None, 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 8}
# 0.880 (+/-0.110) for {'max_features': 'auto', 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 10}
# 0.928 (+/-0.118) for {'max_features': 'auto', 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 10}
# 0.930 (+/-0.090) for {'max_features': 'auto', 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 10}
# 0.941 (+/-0.106) for {'max_features': 'auto', 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 10}
# 0.931 (+/-0.114) for {'max_features': 'auto', 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 10}
# 0.880 (+/-0.110) for {'max_features': 'log2', 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 10}
# 0.928 (+/-0.118) for {'max_features': 'log2', 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 10}
# 0.930 (+/-0.090) for {'max_features': 'log2', 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 10}
# 0.941 (+/-0.106) for {'max_features': 'log2', 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 10}
# 0.931 (+/-0.114) for {'max_features': 'log2', 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 10}
# 0.909 (+/-0.111) for {'max_features': None, 'n_estimators': 3, 'criterion': 'entropy', 'max_depth': 10}
# 0.917 (+/-0.142) for {'max_features': None, 'n_estimators': 10, 'criterion': 'entropy', 'max_depth': 10}
# 0.941 (+/-0.106) for {'max_features': None, 'n_estimators': 50, 'criterion': 'entropy', 'max_depth': 10}
# 0.941 (+/-0.106) for {'max_features': None, 'n_estimators': 100, 'criterion': 'entropy', 'max_depth': 10}
# 0.941 (+/-0.106) for {'max_features': None, 'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 10}
#
# Detailed classification report:
#
# The model is trained on the full training set.
# The scores are computed on the full test set.
#
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.98        90
#           1       0.96      0.92      0.94        26
#
# avg / total       0.97      0.97      0.97       116

# %%
#X_train

# %%
#X_test

# %%
## 95%in10 rule
data['95%in10'] = data['95%in10'].astype(bool)
print('f1', f1_score(data['type'].astype(bool), data['95%in10']))
print('precision', precision_score(data['type'].astype(bool), data['95%in10'], average='binary'))
# Out:
# f1 0.823529411765
# precision 0.768292682927

# %%
tn, fp, fn, tp = confusion_matrix(data['type'].astype(bool), data['95%in10']).ravel()
print((tn, fp, fn, tp))
# false negative
data.loc[data.type &(data['95%in10']==False)]
# Out:
# (296, 19, 8, 63)
#           col_name  nunique  nunique_ratio  H  M  L  ratio_H  ratio_M  \
# 2    education-num       16       0.000491  0  0  5      0.0   0.0000
# 4        education       16       0.000491  0  0  0      0.0   0.0000
# 6       occupation       15       0.000461  0  0  0      0.0   0.0000
# 71           model       13       0.044369  0  3  4      0.0   0.4286
# 328             A5       14       0.020290  0  1  8      0.0   0.1111
# 357        IDENTIF      105       1.000000  0  0  0      0.0   0.0000
# 399          river       42       1.000000  0  0  0      0.0   0.0000
# 400        country       26       0.619048  0  0  0      0.0   0.0000
#
#      ratio_L  dropMean  dropMedian  dropMax  dropMin dtype  95%in10  type
# 2     1.0000    0.0695      0.0555   0.1596      0.0     0    False  True
# 4     0.0000    0.0000      0.0000   0.0000      0.0     2    False  True
# 6     0.0000    0.0000      0.0000   0.0000      0.0     2    False  True
# 71    0.5714    0.2162      0.2524   0.3844      0.0     0    False  True
# 328   0.8889    0.1100      0.0519   0.3225      0.0     0    False  True
# 357   0.0000    0.0000      0.0000   0.0000      0.0     2    False  True
# 399   0.0000    0.0000      0.0000   0.0000      0.0     2    False  True
# 400   0.0000    0.0000      0.0000   0.0000      0.0     2    False  True

# %%
# false postive
data.loc[(data.type==False) & data['95%in10']]
# Out:
#             col_name  nunique  nunique_ratio  H  M   L  ratio_H  ratio_M  \
# 12      capital-gain      119       0.003655  0  0   5   0.0000   0.0000
# 13      capital-loss       92       0.002825  0  0   5   0.0000   0.0000
# 37     UniqueHotkeys       11       0.003295  0  6  13   0.0000   0.3158
# 39   UniqueUnitsMade       12       0.003595  2  2  15   0.1053   0.1053
# 307             bars        5       0.025773  0  1  11   0.0000   0.0833
# 308          stripes       12       0.061856  0  1  11   0.0000   0.0833
# 309          colours        8       0.041237  0  0  12   0.0000   0.0000
# 310          circles        4       0.020619  0  0  12   0.0000   0.0000
# 311          crosses        3       0.015464  1  0  11   0.0833   0.0000
# 312         quarters        3       0.015464  1  0  11   0.0833   0.0000
# 313         sunstars       14       0.072165  0  0  12   0.0000   0.0000
# 355        num_child       15       0.010183  1  0   5   0.1667   0.0000
# 376            col_5       12       0.196721  0  6  11   0.0000   0.3529
# 380           col_16       13       0.213115  4  4   9   0.2353   0.2353
# 381           col_17       12       0.196721  1  8   8   0.0588   0.4706
# 431      diffSaTime1       15       0.000904  0  2  16   0.0000   0.1111
# 432      diffSaTime2        3       0.000181  0  1  17   0.0000   0.0556
# 433      diffSaTime3       12       0.000723  0  2  16   0.0000   0.1111
# 434      diffSaTime4        3       0.000181  0  1  17   0.0000   0.0556
#
#      ratio_L  dropMean  dropMedian  dropMax  dropMin dtype  95%in10   type
# 12    1.0000    0.0637      0.0725   0.1180   0.0000     0     True  False
# 13    1.0000    0.0407      0.0534   0.0677   0.0000     0     True  False
# 37    0.6842    0.1884      0.1661   0.3894   0.0000     0     True  False
# 39    0.7895    0.1654      0.1250   0.5538   0.0000     0     True  False
# 307   0.9167    0.0737      0.0677   0.1732  -0.0106     0     True  False
# 308   0.9167    0.0802      0.0829   0.2228  -0.0187     0     True  False
# 309   1.0000    0.1057      0.0878   0.2582  -0.0079     0     True  False
# 310   1.0000    0.0198      0.0030   0.0678  -0.0000     0     True  False
# 311   0.9167    0.0501      0.0481   0.1503   0.0000     0     True  False
# 312   0.9167    0.0158      0.0109   0.0428   0.0000     0     True  False
# 313   1.0000    0.0479      0.0116   0.2151  -0.0205     0     True  False
# 355   0.8333    0.1367      0.1103   0.5195   0.0000     0     True  False
# 376   0.6471    0.1482      0.1350   0.3556  -0.0022     0     True  False
# 380   0.5294    0.2294      0.2402   0.5703  -0.0770     0     True  False
# 381   0.4706    0.2413      0.2285   0.4577  -0.0046     0     True  False
# 431   0.8889    0.1103      0.0280   0.4755   0.0000     1     True  False
# 432   0.9444    0.0090      0.0132   0.0178   0.0000     1     True  False
# 433   0.8889    0.0763      0.0329   0.4171  -0.0075     1     True  False
# 434   0.9444    0.0072      0.0036   0.0154   0.0000     1     True  False
